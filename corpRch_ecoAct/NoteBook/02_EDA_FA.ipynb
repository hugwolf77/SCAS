# %% [markdown]
# ## Factor Analysis
#
# 2024-09-25
# - 정리된 데이터로 부터 선형 시계열 분석에 용이하도록 또는 해석과 분석에 의미가 있도록 요인분석을 실시한다.
# - base-code 자료는 기존 작성 중이던 app의 코드를 사용한다.
# - 원천 데이터로 부터 컬럼정리 및 정상성 확보는 끝난 데이터를 사용한다. (추후 EDA_01 로 별도 노트정리 고려)

# %% [markdown]
# ### 1. 라이브러리 환경 세팅

# %%
# 기본 라이브러리와 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc('font', family='NanumBarunGothic') 
plt.rcParams['axes.unicode_minus'] =False
# sns.set_style("whitegrid")

# scaler
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# normal distribution test
from scipy.stats import shapiro, kstest
from statsmodels.stats.diagnostic import kstest_normal
from scipy.stats import probplot

# bartlett's, KMO test for equel distribution
from factor_analyzer.factor_analyzer import calculate_kmo, calculate_bartlett_sphericity

# foctor analysis
from factor_analyzer.factor_analyzer import FactorAnalyzer
from sklearn.decomposition import FactorAnalysis as sk_FA
# from statsmodels.multivariate.factor import Factor as sm_FA

# %% [markdown]
# ### 2. DataLoad
#
#  : 원천 데이터로 부터 컬럼정리 및 정상성 확보는 끝난 데이터임.
#
#     - 정상성 확보된 데이터를 사용 (통계적 방법론을 사용하기 위해)
#     - 해석 또는 예측시 차분한 데이터라는 것을 잊어서는 안됨. (직접적인 예측치는 다름)
#     - 상호 영향력 또는 영향력에 의한 변화는 분석 가능함.
#
#  : 기초 데이터 검증을 진행

# %%
# data load
df = pd.read_excel('../data/분석_데이터_목록_v2.xlsx', sheet_name='transData', index_col='date')
print(df.info(),'\n')
print(f"missing data count: {df.isna().sum() } \n")
# missing data row drop
df = df.dropna()
print(f"data missing count after drop missing : {df.isna().sum() } \n")
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 164 entries, 2011-01-01 to 2024-08-01
# Data columns (total 50 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   연구소수          160 non-null    float64
#  1   연구원수(연)       160 non-null    float64
#  2   석박비율(연)       161 non-null    float64
#  3   전담부서수         162 non-null    float64
#  4   연구원수(전)       160 non-null    float64
#  5   석박비율(전)       161 non-null    float64
#  6   경제활동인구        161 non-null    float64
#  7   취업자           161 non-null    float64
#  8   비임금근로자        161 non-null    float64
#  9   고용원이 있는 자영업자  161 non-null    float64
#  10  고용원이 없는 자영업자  161 non-null    float64
#  11  무급가족종사자       161 non-null    float64
#  12  임금근로자         161 non-null    float64
#  13  상용근로자         161 non-null    float64
#  14  임시근로자         161 non-null    float64
#  15  일용근로자         161 non-null    float64
#  16  남자            161 non-null    float64
#  17  여자            161 non-null    float64
#  18  실업자           161 non-null    float64
#  19  실업률           162 non-null    float64
#  20  15세이상인구       162 non-null    float64
#  21  비경제활동인구       161 non-null    float64
#  22  경제활동참가율       161 non-null    float64
#  23  고용률           161 non-null    float64
#  24  경기종합지수_선행     160 non-null    float64
#  25  경기종합지수_동행     160 non-null    float64
#  26  전체산업          160 non-null    float64
#  27  광공업           160 non-null    float64
#  28  건설업           160 non-null    float64
#  29  서비스업          160 non-null    float64
#  30  공공행정          160 non-null    float64
#  31  총수주액          160 non-null    float64
#  32  국내수요          160 non-null    float64
#  33  대리점           160 non-null    float64
#  34  해외수요          160 non-null    float64
#  35  총지수           160 non-null    float64
#  36  설비투자지수        160 non-null    float64
#  37  건설기성액         160 non-null    float64
#  38  기업심리지수전망      164 non-null    float64
#  39  업황전망BSI 1)    164 non-null    int64
#  40  매출전망BSI 2)    163 non-null    float64
#  41  채산성전망BSI 6)   164 non-null    int64
#  42  자금사정전망BSI 6)  164 non-null    int64
#  43  인력사정전망BSI 3)  163 non-null    float64
#  44  기업심리지수실적      163 non-null    float64
#  45  업황실적BSI 1)    163 non-null    float64
#  46  매출실적BSI 2)    163 non-null    float64
#  47  채산성실적BSI 6)   163 non-null    float64
#  48  자금사정실적BSI 6)  163 non-null    float64
#  49  인력사정실적BSI 3)  162 non-null    float64
# dtypes: float64(47), int64(3)
# memory usage: 65.3 KB
# None
#
# missing data count: 연구소수            4
# 연구원수(연)         4
# 석박비율(연)         3
# 전담부서수           2
# 연구원수(전)         4
# 석박비율(전)         3
# 경제활동인구          3
# 취업자             3
# 비임금근로자          3
# 고용원이 있는 자영업자    3
# 고용원이 없는 자영업자    3
# 무급가족종사자         3
# 임금근로자           3
# 상용근로자           3
# 임시근로자           3
# 일용근로자           3
# 남자              3
# 여자              3
# 실업자             3
# 실업률             2
# 15세이상인구         2
# 비경제활동인구         3
# 경제활동참가율         3
# 고용률             3
# 경기종합지수_선행       4
# 경기종합지수_동행       4
# 전체산업            4
# 광공업             4
# 건설업             4
# 서비스업            4
# 공공행정            4
# 총수주액            4
# 국내수요            4
# 대리점             4
# 해외수요            4
# 총지수             4
# 설비투자지수          4
# 건설기성액           4
# 기업심리지수전망        0
# 업황전망BSI 1)      0
# 매출전망BSI 2)      1
# 채산성전망BSI 6)     0
# 자금사정전망BSI 6)    0
# 인력사정전망BSI 3)    1
# 기업심리지수실적        1
# 업황실적BSI 1)      1
# 매출실적BSI 2)      1
# 채산성실적BSI 6)     1
# 자금사정실적BSI 6)    1
# 인력사정실적BSI 3)    2
# dtype: int64
#
# data missing count after drop missing : 연구소수            0
# 연구원수(연)         0
# 석박비율(연)         0
# 전담부서수           0
# 연구원수(전)         0
# 석박비율(전)         0
# 경제활동인구          0
# 취업자             0
# 비임금근로자          0
# 고용원이 있는 자영업자    0
# 고용원이 없는 자영업자    0
# 무급가족종사자         0
# 임금근로자           0
# 상용근로자           0
# 임시근로자           0
# 일용근로자           0
# 남자              0
# 여자              0
# 실업자             0
# 실업률             0
# 15세이상인구         0
# 비경제활동인구         0
# 경제활동참가율         0
# 고용률             0
# 경기종합지수_선행       0
# 경기종합지수_동행       0
# 전체산업            0
# 광공업             0
# 건설업             0
# 서비스업            0
# 공공행정            0
# 총수주액            0
# 국내수요            0
# 대리점             0
# 해외수요            0
# 총지수             0
# 설비투자지수          0
# 건설기성액           0
# 기업심리지수전망        0
# 업황전망BSI 1)      0
# 매출전망BSI 2)      0
# 채산성전망BSI 6)     0
# 자금사정전망BSI 6)    0
# 인력사정전망BSI 3)    0
# 기업심리지수실적        0
# 업황실적BSI 1)      0
# 매출실적BSI 2)      0
# 채산성실적BSI 6)     0
# 자금사정실적BSI 6)    0
# 인력사정실적BSI 3)    0
# dtype: int64
#
#               연구소수       연구원수(연)     석박비율(연)       전담부서수      연구원수(전)  \
# count   159.000000    159.000000  159.000000  159.000000   159.000000
# mean     -2.490566     -2.452830    0.000002    9.953139     0.735849
# std     312.474037   4321.908462    0.000681    0.458173   344.914270
# min   -2287.000000 -19107.000000   -0.002451    9.004177 -1027.000000
# 25%    -125.500000  -1003.000000   -0.000410    9.607598  -122.500000
# 50%      -6.000000    -10.000000    0.000071   10.114194   -22.000000
# 75%      99.500000    852.500000    0.000467   10.330561   123.000000
# max    1471.000000  36852.000000    0.001521   10.487824  1384.000000
#
#           석박비율(전)      경제활동인구         취업자      비임금근로자  고용원이 있는 자영업자  ...  \
# count  159.000000  159.000000  159.000000  159.000000    159.000000  ...
# mean    -0.000089   26.006289   26.603774   -2.610063     -0.710692  ...
# std      0.000716  100.278757  108.073347   35.726264     17.958231  ...
# min     -0.002139 -570.000000 -677.000000 -106.000000    -73.000000  ...
# 25%     -0.000524  -25.500000  -17.000000  -25.500000    -11.000000  ...
# 50%     -0.000032   29.000000   41.000000   -2.000000     -1.000000  ...
# 75%      0.000335   74.000000   82.000000   18.000000     11.500000  ...
# max      0.001727  290.000000  424.000000   97.000000     50.000000  ...
#
#        매출전망BSI 2)  채산성전망BSI 6)  자금사정전망BSI 6)  인력사정전망BSI 3)    기업심리지수실적  \
# count  159.000000   159.000000    159.000000    159.000000  159.000000
# mean    -0.119497    84.377358     83.924528     -0.056604   97.657862
# std      3.372196     3.974092      4.209013      1.467993    7.901109
# min    -18.000000    70.000000     64.000000     -5.000000   66.400000
# 25%     -2.000000    82.500000     82.000000     -1.000000   93.650000
# 50%      0.000000    85.000000     84.000000      0.000000   96.800000
# 75%      2.000000    87.000000     86.000000      1.000000  102.400000
# max      8.000000    91.000000     93.000000      3.000000  114.100000
#
#        업황실적BSI 1)  매출실적BSI 2)  채산성실적BSI 6)  자금사정실적BSI 6)  인력사정실적BSI 3)
# count  159.000000  159.000000   159.000000    159.000000    159.000000
# mean    74.578616   83.553459    83.698113     83.534591     -0.044025
# std      6.974986    8.911412     3.862764      3.931019      1.481301
# min     51.000000   52.000000    70.000000     66.000000     -6.000000
# 25%     70.000000   79.000000    82.000000     82.000000     -1.000000
# 50%     74.000000   82.000000    85.000000     84.000000      0.000000
# 75%     78.500000   88.000000    86.000000     86.000000      1.000000
# max     92.000000  103.000000    90.000000     90.000000      3.000000
#
# [8 rows x 50 columns]

# %%
# scaling
scaler = StandardScaler() 
scaled = scaler.fit_transform(df)

print(f"df.shape:{df.shape}")

cols = df.columns
idx = df.index
dfs = pd.DataFrame(scaled, columns=cols, index=idx)

# hand made
# mean = df.mean()
# std = df.std()
# scaled = (df - mean)/std 

print(f"dfs.shape:{dfs.shape}")

dfs.describe().transpose()
# Out:
# df.shape:(159, 50)
# dfs.shape:(159, 50)
#               count          mean      std       min       25%       50%  \
# 연구소수          159.0  4.887774e-18  1.00316 -7.334137 -0.394907 -0.011267
# 연구원수(연)       159.0  1.187031e-17  1.00316 -4.434363 -0.232237 -0.001752
# 석박비율(연)       159.0  0.000000e+00  1.00316 -3.615414 -0.606442  0.101664
# 전담부서수         159.0 -8.043880e-16  1.00316 -2.077731 -0.756554  0.352627
# 연구원수(전)       159.0 -5.586028e-18  1.00316 -2.989099 -0.358423 -0.066126
# 석박비율(전)       159.0  4.468822e-17  1.00316 -2.871130 -0.609648  0.079289
# 경제활동인구        159.0  2.793014e-17  1.00316 -5.962274 -0.515254  0.029948
# 취업자           159.0 -1.117206e-17  1.00316 -6.530998 -0.404739  0.133629
# 비임금근로자        159.0  2.793014e-18  1.00316 -2.903091 -0.642728  0.017130
# 고용원이 있는 자영업자  159.0 -2.793014e-17  1.00316 -4.038132 -0.574768 -0.016161
# 고용원이 없는 자영업자  159.0  1.536158e-17  1.00316 -2.448294 -0.684448 -0.068164
# 무급가족종사자       159.0 -1.675808e-17  1.00316 -3.068922 -0.624512  0.027331
# 임금근로자         159.0  1.675808e-17  1.00316 -6.005148 -0.469519  0.101463
# 상용근로자         159.0  4.748124e-17  1.00316 -3.992462 -0.453468 -0.005494
# 임시근로자         159.0 -9.077295e-18  1.00316 -5.551870 -0.395961  0.001667
# 일용근로자         159.0  2.793014e-18  1.00316 -5.423508 -0.527072  0.014361
# 남자            159.0  2.793014e-17  1.00316 -4.853212 -0.474486  0.110028
# 여자            159.0 -1.955110e-17  1.00316 -6.798584 -0.291346  0.058820
# 실업자           159.0  1.117206e-17  1.00316 -3.342496 -0.572995 -0.038250
# 실업률           159.0  0.000000e+00  0.00000  0.000000  0.000000  0.000000
# 15세이상인구       159.0 -2.770670e-15  1.00316 -2.023848 -0.791352  0.163408
# 비경제활동인구       159.0 -6.982535e-18  1.00316 -2.574612 -0.579060 -0.023906
# 경제활동참가율       159.0 -1.396507e-17  1.00316 -5.593774 -0.509009 -0.085279
# 고용률           159.0  1.117206e-17  1.00316 -6.256127 -0.503901 -0.093028
# 경기종합지수_선행     159.0 -5.586028e-17  1.00316 -2.660228 -0.788652  0.147136
# 경기종합지수_동행     159.0  5.586028e-17  1.00316 -3.929345 -0.353682 -0.028622
# 전체산업          159.0 -2.024935e-17  1.00316 -3.387045 -0.660259  0.021437
# 광공업           159.0  7.680788e-18  1.00316 -3.725279 -0.695262  0.037806
# 건설업           159.0  0.000000e+00  1.00316 -3.272641 -0.514097  0.058431
# 서비스업          159.0 -1.117206e-17  1.00316 -5.549067 -0.499422 -0.004359
# 공공행정          159.0  6.982535e-19  1.00316 -3.682039 -0.494644 -0.028196
# 총수주액          159.0  3.491267e-17  1.00316 -3.009689 -0.640933 -0.025442
# 국내수요          159.0 -6.284281e-18  1.00316 -3.939535 -0.486896 -0.043546
# 대리점           159.0 -2.932665e-17  1.00316 -4.966721 -0.455172  0.111164
# 해외수요          159.0 -1.536158e-17  1.00316 -3.018263 -0.669065  0.006550
# 총지수           159.0  4.468822e-17  1.00316 -2.679922 -0.662072 -0.047943
# 설비투자지수        159.0  4.887774e-17  1.00316 -2.655618 -0.804388  0.029683
# 건설기성액         159.0  2.793014e-18  1.00316 -4.023149 -0.526627  0.093376
# 기업심리지수전망      159.0 -8.379042e-16  1.00316 -4.049931 -0.494775 -0.038986
# 업황전망BSI 1)    159.0 -9.810461e-17  1.00316 -3.613852 -0.529867 -0.109324
# 매출전망BSI 2)    159.0  4.887774e-18  1.00316 -5.319085 -0.559411  0.035548
# 채산성전망BSI 6)   159.0 -2.234411e-16  1.00316 -3.629202 -0.473892  0.157170
# 자금사정전망BSI 6)  159.0 -6.703233e-16  1.00316 -4.748734 -0.458685  0.017988
# 인력사정전망BSI 3)  159.0  9.775549e-18  1.00316 -3.378092 -0.644674  0.038680
# 기업심리지수실적      159.0 -4.859844e-16  1.00316 -3.968636 -0.508856 -0.108918
# 업황실적BSI 1)    159.0  9.049365e-16  1.00316 -3.391134 -0.658508 -0.083218
# 매출실적BSI 2)    159.0  6.088770e-16  1.00316 -3.551980 -0.512584 -0.174873
# 채산성실적BSI 6)   159.0  9.607968e-16  1.00316 -3.557399 -0.441000  0.338100
# 자금사정실적BSI 6)  159.0 -6.032910e-16  1.00316 -4.474665 -0.391613  0.118768
# 인력사정실적BSI 3)  159.0 -3.421442e-17  1.00316 -4.033477 -0.647401  0.029815
#
#                    75%       max
# 연구소수          0.327428  4.730461
# 연구원수(연)       0.198443  8.554299
# 석박비율(연)       0.685505  2.238369
# 전담부서수         0.826358  1.170681
# 연구원수(전)       0.355597  4.023129
# 석박비율(전)       0.593407  2.543120
# 경제활동인구        0.480115  2.640916
# 취업자           0.514199  3.688715
# 비임금근로자        0.578711  2.796956
# 고용원이 있는 자영업자  0.682098  2.832735
# 고용원이 없는 자영업자  0.654375  3.034506
# 무급가족종사자       0.570533  3.721107
# 임금근로자         0.517603  3.798334
# 상용근로자         0.621669  2.346369
# 임시근로자         0.439058  3.991201
# 일용근로자         0.591105  2.886309
# 남자            0.571486  2.858268
# 여자            0.452756  3.750145
# 실업자           0.464570  3.840648
# 실업률           0.000000  0.000000
# 15세이상인구       0.920687  1.365612
# 비경제활동인구       0.556255  5.817711
# 경제활동참가율       0.550317  2.880834
# 고용률           0.523282  3.604832
# 경기종합지수_선행     0.615031  2.954501
# 경기종합지수_동행     0.621499  2.571860
# 전체산업          0.703133  2.845608
# 광공업           0.673132  2.774595
# 건설업           0.526863  3.233360
# 서비스업          0.589717  2.470957
# 공공행정          0.425296  4.299407
# 총수주액          0.475755  3.108437
# 국내수요          0.463650  4.329547
# 대리점           0.593311  2.284654
# 해외수요          0.483988  3.172318
# 총지수           0.566185  3.344385
# 설비투자지수        0.558606  2.450523
# 건설기성액         0.490796  3.814425
# 기업심리지수전망      0.592608  2.409254
# 업황전망BSI 1)    0.591582  2.554118
# 매출전망BSI 2)    0.630507  2.415385
# 채산성전망BSI 6)   0.662020  1.671719
# 자금사정전망BSI 6)  0.494660  2.163012
# 인력사정전망BSI 3)  0.722035  2.088744
# 기업심리지수실적      0.602083  2.087566
# 업황실적BSI 1)    0.563983  2.505586
# 매출실적BSI 2)    0.500548  2.189101
# 채산성실적BSI 6)   0.597800  1.636600
# 자금사정실적BSI 6)  0.629149  1.649912
# 인력사정실적BSI 3)  0.707030  2.061460

# %%
# feature 가 50개라서 나눠서 그래프 살펴봄
col = dfs.columns
dfs_s = dfs.iloc[:,1:2]
dfs_s.plot()
# Out:
# <Axes: xlabel='date'>

# %%
# data load
df_raw = pd.read_excel('../data/분석_데이터_목록_v2.xlsx', sheet_name='variable', index_col='date')
df_raw
df_raw_s = df_raw.iloc[:,0:1]
df_raw_s.plot()
# Out:
# <Axes: xlabel='date'>

# %%
# 바이올린
dfss = dfs.melt(var_name='Column', value_name='Normalized')
plt.figure(figsize=(18, 8))
ax = sns.violinplot(x='Column', y='Normalized', data=dfss, hue='Column')
ax.xaxis.set_ticks(dfs.keys())
ax.set_xticklabels(dfs.keys(), rotation=90)
# Out:
# [Text(0.0, 0, '연구소수'),
#  Text(1.0, 0, '연구원수(연)'),
#  Text(2.0, 0, '석박비율(연)'),
#  Text(3.0, 0, '전담부서수'),
#  Text(4.0, 0, '연구원수(전)'),
#  Text(5.0, 0, '석박비율(전)'),
#  Text(6.0, 0, '경제활동인구'),
#  Text(7.0, 0, '취업자'),
#  Text(8.0, 0, '비임금근로자'),
#  Text(9.0, 0, '고용원이 있는 자영업자'),
#  Text(10.0, 0, '고용원이 없는 자영업자'),
#  Text(11.0, 0, '무급가족종사자'),
#  Text(12.0, 0, '임금근로자'),
#  Text(13.0, 0, '상용근로자'),
#  Text(14.0, 0, '임시근로자'),
#  Text(15.0, 0, '일용근로자'),
#  Text(16.0, 0, '남자'),
#  Text(17.0, 0, '여자'),
#  Text(18.0, 0, '실업자'),
#  Text(19.0, 0, '실업률'),
#  Text(20.0, 0, '15세이상인구'),
#  Text(21.0, 0, '비경제활동인구'),
#  Text(22.0, 0, '경제활동참가율'),
#  Text(23.0, 0, '고용률'),
#  Text(24.0, 0, '경기종합지수_선행'),
#  Text(25.0, 0, '경기종합지수_동행'),
#  Text(26.0, 0, '전체산업'),
#  Text(27.0, 0, '광공업'),
#  Text(28.0, 0, '건설업'),
#  Text(29.0, 0, '서비스업'),
#  Text(30.0, 0, '공공행정'),
#  Text(31.0, 0, '총수주액'),
#  Text(32.0, 0, '국내수요'),
#  Text(33.0, 0, '대리점'),
#  Text(34.0, 0, '해외수요'),
#  Text(35.0, 0, '총지수'),
#  Text(36.0, 0, '설비투자지수'),
#  Text(37.0, 0, '건설기성액'),
#  Text(38.0, 0, '기업심리지수전망'),
#  Text(39.0, 0, '업황전망BSI 1)'),
#  Text(40.0, 0, '매출전망BSI 2)'),
#  Text(41.0, 0, '채산성전망BSI 6)'),
#  Text(42.0, 0, '자금사정전망BSI 6)'),
#  Text(43.0, 0, '인력사정전망BSI 3)'),
#  Text(44.0, 0, '기업심리지수실적'),
#  Text(45.0, 0, '업황실적BSI 1)'),
#  Text(46.0, 0, '매출실적BSI 2)'),
#  Text(47.0, 0, '채산성실적BSI 6)'),
#  Text(48.0, 0, '자금사정실적BSI 6)'),
#  Text(49.0, 0, '인력사정실적BSI 3)')]

# %%
# boxplot
plt.figure(figsize=(18, 8))
ax = sns.boxplot(x='Column', y='Normalized', data=dfss, hue='Column')
ax.xaxis.set_ticks(dfs.keys())
ax.set_xticklabels(dfs.keys(), rotation=90)
# Out:
# [Text(0.0, 0, '연구소수'),
#  Text(1.0, 0, '연구원수(연)'),
#  Text(2.0, 0, '석박비율(연)'),
#  Text(3.0, 0, '전담부서수'),
#  Text(4.0, 0, '연구원수(전)'),
#  Text(5.0, 0, '석박비율(전)'),
#  Text(6.0, 0, '경제활동인구'),
#  Text(7.0, 0, '취업자'),
#  Text(8.0, 0, '비임금근로자'),
#  Text(9.0, 0, '고용원이 있는 자영업자'),
#  Text(10.0, 0, '고용원이 없는 자영업자'),
#  Text(11.0, 0, '무급가족종사자'),
#  Text(12.0, 0, '임금근로자'),
#  Text(13.0, 0, '상용근로자'),
#  Text(14.0, 0, '임시근로자'),
#  Text(15.0, 0, '일용근로자'),
#  Text(16.0, 0, '남자'),
#  Text(17.0, 0, '여자'),
#  Text(18.0, 0, '실업자'),
#  Text(19.0, 0, '실업률'),
#  Text(20.0, 0, '15세이상인구'),
#  Text(21.0, 0, '비경제활동인구'),
#  Text(22.0, 0, '경제활동참가율'),
#  Text(23.0, 0, '고용률'),
#  Text(24.0, 0, '경기종합지수_선행'),
#  Text(25.0, 0, '경기종합지수_동행'),
#  Text(26.0, 0, '전체산업'),
#  Text(27.0, 0, '광공업'),
#  Text(28.0, 0, '건설업'),
#  Text(29.0, 0, '서비스업'),
#  Text(30.0, 0, '공공행정'),
#  Text(31.0, 0, '총수주액'),
#  Text(32.0, 0, '국내수요'),
#  Text(33.0, 0, '대리점'),
#  Text(34.0, 0, '해외수요'),
#  Text(35.0, 0, '총지수'),
#  Text(36.0, 0, '설비투자지수'),
#  Text(37.0, 0, '건설기성액'),
#  Text(38.0, 0, '기업심리지수전망'),
#  Text(39.0, 0, '업황전망BSI 1)'),
#  Text(40.0, 0, '매출전망BSI 2)'),
#  Text(41.0, 0, '채산성전망BSI 6)'),
#  Text(42.0, 0, '자금사정전망BSI 6)'),
#  Text(43.0, 0, '인력사정전망BSI 3)'),
#  Text(44.0, 0, '기업심리지수실적'),
#  Text(45.0, 0, '업황실적BSI 1)'),
#  Text(46.0, 0, '매출실적BSI 2)'),
#  Text(47.0, 0, '채산성실적BSI 6)'),
#  Text(48.0, 0, '자금사정실적BSI 6)'),
#  Text(49.0, 0, '인력사정실적BSI 3)')]

# %% [markdown]
# - 실업률 컬럼에 대해서는 의미가 없기 때문에 drop 처리
# - 요인추출 전 기본 측정 변수들에 대해서 상관계수 확인

# %%
print(f"drop col 전 컬럼 확인 : {dfs.columns}")
print(f"drop col '실업자' : {cols[19]}")
dfsf = dfs.drop(labels=cols[19], axis=1)
print(f"drop col 후 컬럼 확인 : {dfsf.columns}")
# Out:
# drop col 전 컬럼 확인 : Index(['연구소수', '연구원수(연)', '석박비율(연)', '전담부서수', '연구원수(전)', '석박비율(전)', '경제활동인구',
#        '취업자', '비임금근로자', '고용원이 있는 자영업자', '고용원이 없는 자영업자', '무급가족종사자', '임금근로자',
#        '상용근로자', '임시근로자', '일용근로자', '남자', '여자', '실업자', '실업률', '15세이상인구',
#        '비경제활동인구', '경제활동참가율', '고용률', '경기종합지수_선행', '경기종합지수_동행', '전체산업', '광공업',
#        '건설업', '서비스업', '공공행정', '총수주액', '국내수요', '대리점', '해외수요', '총지수', '설비투자지수',
#        '건설기성액', '기업심리지수전망', '업황전망BSI 1)', '매출전망BSI 2)', '채산성전망BSI 6)',
#        '자금사정전망BSI 6)', '인력사정전망BSI 3)', '기업심리지수실적', '업황실적BSI 1)', '매출실적BSI 2)',
#        '채산성실적BSI 6)', '자금사정실적BSI 6)', '인력사정실적BSI 3)'],
#       dtype='object')
# drop col '실업자' : 실업률
# drop col 후 컬럼 확인 : Index(['연구소수', '연구원수(연)', '석박비율(연)', '전담부서수', '연구원수(전)', '석박비율(전)', '경제활동인구',
#        '취업자', '비임금근로자', '고용원이 있는 자영업자', '고용원이 없는 자영업자', '무급가족종사자', '임금근로자',
#        '상용근로자', '임시근로자', '일용근로자', '남자', '여자', '실업자', '15세이상인구', '비경제활동인구',
#        '경제활동참가율', '고용률', '경기종합지수_선행', '경기종합지수_동행', '전체산업', '광공업', '건설업',
#        '서비스업', '공공행정', '총수주액', '국내수요', '대리점', '해외수요', '총지수', '설비투자지수', '건설기성액',
#        '기업심리지수전망', '업황전망BSI 1)', '매출전망BSI 2)', '채산성전망BSI 6)', '자금사정전망BSI 6)',
#        '인력사정전망BSI 3)', '기업심리지수실적', '업황실적BSI 1)', '매출실적BSI 2)', '채산성실적BSI 6)',
#        '자금사정실적BSI 6)', '인력사정실적BSI 3)'],
#       dtype='object')

# %%
# 상관계수 확인 (요인추출 전)
cor_dfsf = dfsf.corr()
cor_dfsf # 차원이 49차원이라 눈으로 확인하기 어려움
sns.clustermap(cor_dfsf, 
               annot = True,      # 실제 값 화면에 나타내기
               cmap = 'RdYlBu_r',  # Red, Yellow, Blue 색상으로 표시
               vmin = -1, vmax = 1, #컬러차트 -1 ~ 1 범위로 표시
              )

# %% [markdown]
# - 요인분석 전 기초 위 상관관계 표에서도 3 ~ 5 정도의 요인으로 분류 될 것으로 예상됨.
# - 이를 기초로 "EFA" 진행

# %%
# from sklearn.cluster import KMeans
# kms = KMeans(n_clusters=5, init='k-means++', max_iter=300, random_state=0)
# kms.fit(dfsf)

# %% [markdown]
# ### 3. 탐색적 요인 분석 (EFA) - 본격적 요인분석
#
#     : 기존 app에서 사용한 기법을 위주로 시간 가능하면 주가 라이브러리들 고려 (24.09.25)
#         -

# %% [markdown]
# #### 3-1 요인분석 적합성 검정
#
#  - Bartlett test
#  - KMO(Kaiser-Meyer-Olkin) test

# %%
def normDist_test(data):
    chi_square_value,p_value=calculate_bartlett_sphericity(data)
    print(f"chi_square_value : {chi_square_value}")
    print(f"p_value() :{p_value}")

    kmo, p_value = calculate_kmo(data)
    print(f"kmo_all : {kmo}")
    print(f"kmo_model :{p_value}")


normDist_test(dfsf)
# Out:
# chi_square_value : nan
# p_value() :nan
# kmo_all : [0.57625261 0.55219599 0.53957409 0.56302686 0.64098769 0.73934574
#  0.76527378 0.84057766 0.49717276 0.30297394 0.24269815 0.38461001
#  0.67409919 0.3821398  0.54153051 0.44303461 0.78828312 0.79970713
#  0.42313134 0.58798634 0.9331034  0.94474375 0.95093889 0.52920748
#  0.88295067 0.44036039 0.21945667 0.44401055 0.4146772  0.09735022
#  0.5530562  0.51842015 0.29873716 0.50069009 0.7757255  0.64397584
#  0.76751887 0.78254794 0.80300145 0.70889536 0.87540505 0.83074908
#  0.43565297 0.76063674 0.80330438 0.80523357 0.85250335 0.83664031
#  0.39283253]
# kmo_model :0.6677238812637188
# /home/augustine77/.cache/pypoetry/virtualenvs/scas-EkJwidcN-py3.11/lib/python3.11/site-packages/factor_analyzer/factor_analyzer.py:109: RuntimeWarning: invalid value encountered in log
#   statistic = -np.log(corr_det) * (n - 1 - (2 * p + 5) / 6)
# /home/augustine77/.cache/pypoetry/virtualenvs/scas-EkJwidcN-py3.11/lib/python3.11/site-packages/factor_analyzer/utils.py:244: UserWarning: The inverse of the variance-covariance matrix was calculated using the Moore-Penrose generalized matrix inversion, due to its determinant being at or very close to zero.
#   warnings.warn(

# %% [markdown]
# - 기초 전체 요인으로 분석
# - 전체 데이터에서는 eigenvalue 로 살펴볼 때 10~18 로 보임.

# %%
# 특성변수 전체 49개 진행
fa_base = FactorAnalyzer(n_factors=49,rotation=None)
fa_base.fit(dfsf)

#Eigen값 체크 
ev, v = fa_base.get_eigenvalues()
print(f"eigenvalue: \n {ev}")

plt.scatter(range(1,50),ev)
plt.plot(range(1,50),ev)
plt.hlines(1,1,50, colors='r')
plt.vlines(10,0,12, colors='g', ls=':')
plt.title('Scree Plot')
plt.xlabel('Factors')
plt.ylabel('Eigenvalue')
plt.show()
# Out:
# eigenvalue:
#  [1.08401373e+01 6.76454614e+00 3.10293676e+00 2.80180863e+00
#  2.65157386e+00 2.16815104e+00 2.10962767e+00 1.65565669e+00
#  1.58839455e+00 1.31183427e+00 1.20715856e+00 1.17660958e+00
#  1.07752447e+00 1.04447875e+00 9.92139716e-01 9.72118487e-01
#  9.50021964e-01 8.52824029e-01 7.71874131e-01 6.72811674e-01
#  5.74537430e-01 5.33797404e-01 4.91548231e-01 4.39534677e-01
#  3.85488958e-01 3.55250326e-01 3.22221799e-01 2.77098690e-01
#  2.06524592e-01 2.01782783e-01 1.52524014e-01 1.04753412e-01
#  5.82502104e-02 4.51789456e-02 3.40988170e-02 2.82084110e-02
#  2.28066738e-02 1.98595999e-02 1.55817306e-02 7.12776476e-03
#  3.91814640e-03 3.35168270e-03 2.37166953e-03 1.69866782e-03
#  1.96513410e-04 2.52294884e-05 2.22104622e-05 1.31887937e-05
#  3.03646912e-16]

# %%
factor = 3

fa_01 = FactorAnalyzer(n_factors=factor, rotation="varimax") #ml : 최대우도 방법
fa_01.fit(dfsf)
efa_result = pd.DataFrame(fa_01.loadings_, index=dfsf.columns)
# efa_result

# %%
efa_rs = efa_result.round(3).sort_values(by=[k for k  in range(0,factor)],ascending=False)
# efa_rs
# efa_rs.to_excel("./result/efa_01.xlsx")

# %%
plt.figure(figsize=(6,10))
sns.heatmap(efa_rs, cmap="Blues", annot=True, fmt='.2f')
# Out:
# <Axes: >

# %%
# 설명력
var = pd.DataFrame(fa_01.get_factor_variance(), index= ['SS-Loading','Proportion Var','Cumulative Var'])
var

# fa.fit_transform(X) ## 변환
# Out:
#                        0         1         2         3         4         5  \
# SS-Loading      8.386008  7.777699  2.696752  2.353258  2.219295  2.031968
# Proportion Var  0.171143  0.158729  0.055036  0.048026  0.045292  0.041469
# Cumulative Var  0.171143  0.329872  0.384907  0.432933  0.478225  0.519693
#
#                        6         7         8         9
# SS-Loading      2.028566  1.787501  1.748963  1.260166
# Proportion Var  0.041399  0.036480  0.035693  0.025718
# Cumulative Var  0.561093  0.597572  0.633265  0.658983

# %% [markdown]
# ### scikit-learn - fa

# %%
fa_02 = sk_FA(n_components=factor, rotation='varimax').fit(dfsf)
ff = pd.DataFrame(fa_02.components_)
efa_result_02 = ff.T
efa_result_02.index=dfsf.columns
efa_rs_02 = efa_result_02.round(3).sort_values(by=[k for k  in range(0,factor)],ascending=False)
plt.figure(figsize=(6,10))
sns.heatmap(efa_rs_02, cmap="Blues", annot=True, fmt='.2f')
# Out:
# <Axes: >
